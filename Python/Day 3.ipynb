# %%
name  = "Liqzan"

# %%
name
# Out:
# 'Liqzan'

# %%
name = input("Enter the name :")
# Out:
# Enter the name :Manna

# %%
name
# Out:
# 'Manna'

# %%
score = input("Enter your score :")
# Out:
# Enter your score :65

# %%
score
# Out:
# '65'

# %%
type(score)
# Out:
# str

# %%
score = int(input("Enter your score :"))
# Out:
# Enter your score :65

# %%
score
# Out:
# 70

# %%
type(score)
# Out:
# int

# %% [markdown]
# hello Liqzan, your score is 65

# %%
print("Dear " + name + ", your score is " + str(score))
# Out:
# Dear Manna, your score is 65

# %%
print(f"Dear {name}, your score is {score}")
# Out:
# Dear Manna, your score is 65

# %%
print("Dear", name, "your score is", score)
# Out:
# Dear Manna your score is 65

# %% [markdown]
# Assignment
# 1. Take the user's name
# 2. Take the user's weight in Kgs
# 3. Print the statement in pounds

# %% [markdown]
# Conditions

# %%
temp = int(input("Please enter the temperature : \n"))

if temp > 35:
  print("It's a Hot day here")

elif temp < 17:
  print("It's cold out there")

else:
  print("It's a pleasant day")
# Out:
# Please enter the temperature :
# 11
# It's cold out there

# %% [markdown]
# Assignment 2 :
# 1. Take the user name of user:
# 2. username should be in between 3-10 chars
# 3. if not, then give the error message to the user

# %%
name=input("enter the name : \n")
