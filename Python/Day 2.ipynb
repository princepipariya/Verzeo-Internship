# %%
print("Hello World")
# Out:
# Hello World

# %%
5 > 9
# Out:
# False

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('My name\'s Liqzan')
# Out:
# My name's Liqzan

# %%
print("My name's Liqzan")
# Out:
# My name's Liqzan

# %%
print('''You can use this''')
# Out:
# You can use this

# %%
course = "Python for beginners"

# %%
print(course)
# Out:
# Python for beginners

# %%
print(type(course))
# Out:
# <class 'str'>

# %%
course
# Out:
# 'Python for beginners'

# %%
name = "Liqzan"

# %%
print(course)
print(name)
# Out:
# Python for beginners
# Liqzan

# %%
address = "My address is in Bangalore"

# %%
address
# Out:
# 'My address is in Bangalore'

# %%
type(address)
# Out:
# str

# %%
num = 23

# %%
type(num)
# Out:
# int

# %%
num = "23.0"

# %%
type(num)
# Out:
# str
