# %%
high_income = True
good_credit_score = False

if high_income and good_credit_score:
  print("Eligible for Loan")

else:
  print("Not Eligible")
# Out:
# Not Eligible

# %%
high_income = True
good_credit_score = False

if high_income or good_credit_score:
  print("Eligible for Loan")

else:
  print("Not Eligible")
# Out:
# Eligible for Loan

# %% [markdown]
# Assignment:
# 1. Price of the house is 100000
# 2. Check credit history of applicant
# 3. If good, they pay 10% of the amount as down payment
# 4. If not, they pay 20%
# 5. Print the statement of how much amount has to be paid

# %%
for number in range(0,10,2):
  print(number)
print("Done")
# Out:
# 0
# 2
# 4
# 6
# 8
# Done

# %%
number
# Out:
# 4

# %%
for number in range(0,10):
  print("Iteration", number)
print("Done")
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Done
